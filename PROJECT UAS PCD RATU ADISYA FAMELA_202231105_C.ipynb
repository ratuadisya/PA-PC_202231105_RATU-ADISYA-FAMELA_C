# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('fotoratuu.jpg')

# %%
# Display the original image
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Citra Asli')

# Display the original image again
plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('After Filter Median')
 
# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply median filtering
median = cv2.medianBlur(gray, 5)

# Display the median filtered image
plt.subplot(2, 2, 3)
plt.imshow(median, cmap='gray')
plt.title('Original Image')

kernel = np.ones((5, 5), np.float32) / 25

def mean_filter_manual(image, kernel):
    pad_size = kernel.shape[0] // 2
    padded_image = np.pad(image, ((pad_size, pad_size), (pad_size, pad_size)), mode='constant')
    filtered_image = np.zeros_like(image)

    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            filtered_image[i, j] = np.sum(padded_image[i:i+kernel.shape[0], j:j+kernel.shape[1]] * kernel)
    
    return filtered_image

mean = mean_filter_manual(gray, kernel)

# Display the mean filtered image
plt.subplot(2, 2, 4)
plt.imshow(mean, cmap='gray')
plt.title('Mean Filtered Image')

plt.show()
